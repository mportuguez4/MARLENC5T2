# %%
import pandas as pd

# %%
prueba = pd.read_csv('titanic.csv', header =1)

# %%
print(prueba)
# Out:
#          1  1st  survived  female         29  0  0.1
# 0        2  1st  survived    male     0.9167  1    2
# 1        3  1st      died  female     2.0000  1    2
# 2        4  1st      died    male    30.0000  1    2
# 3        5  1st      died  female    25.0000  1    2
# 4        6  1st  survived    male    48.0000  0    0
# ...    ...  ...       ...     ...        ... ..  ...
# 1303  1305  3rd      died  female    14.5000  1    0
# 1304  1306  3rd      died  female  9999.0000  1    0
# 1305  1307  3rd      died    male    26.5000  0    0
# 1306  1308  3rd      died    male    27.0000  0    0
# 1307  1309  3rd      died    male    29.0000  0    0
#
# [1308 rows x 7 columns]

# %%
credit = pd.read_csv('default of credit card clients.csv', header =1)

# %%
print(credit)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1      20000    2          2         1   24      2      2     -1
# 1          2     120000    2          2         2   26     -1      2      0
# 2          3      90000    2          2         2   34      0      0      0
# 3          4      50000    2          2         1   37      0      0      0
# 4          5      50000    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
# ...

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %%
credit.median()
# Out:
# ID                             15000.5
# LIMIT_BAL                     140000.0
# SEX                                2.0
# EDUCATION                          2.0
# MARRIAGE                           2.0
# AGE                               34.0
# PAY_0                              0.0
# PAY_2                              0.0
# PAY_3                              0.0
# PAY_4                              0.0
# PAY_5                              0.0
# PAY_6                              0.0
# BILL_AMT1                      22381.5
# BILL_AMT2                      21200.0
# BILL_AMT3                      20088.5
# BILL_AMT4                      19052.0
# BILL_AMT5                      18104.5
# BILL_AMT6                      17071.0
# PAY_AMT1                        2100.0
# PAY_AMT2                        2009.0
# PAY_AMT3                        1800.0
# PAY_AMT4                        1500.0
# PAY_AMT5                        1500.0
# PAY_AMT6                        1500.0
# ...

# %%
type(credit)
# Out:
# pandas.core.frame.DataFrame

# %%
credit.dtypes
# Out:
# ID                            int64
# LIMIT_BAL                     int64
# SEX                           int64
# EDUCATION                     int64
# MARRIAGE                      int64
# AGE                           int64
# PAY_0                         int64
# PAY_2                         int64
# PAY_3                         int64
# PAY_4                         int64
# PAY_5                         int64
# PAY_6                         int64
# BILL_AMT1                     int64
# BILL_AMT2                     int64
# BILL_AMT3                     int64
# BILL_AMT4                     int64
# BILL_AMT5                     int64
# BILL_AMT6                     int64
# PAY_AMT1                      int64
# PAY_AMT2                      int64
# PAY_AMT3                      int64
# PAY_AMT4                      int64
# PAY_AMT5                      int64
# PAY_AMT6                      int64
# default payment next month    int64
# dtype: object

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# ...

# %%
pd.isna(credit)
# Out:
#           ID  LIMIT_BAL    SEX  EDUCATION  MARRIAGE    AGE  PAY_0  PAY_2  \
# 0      False      False  False      False     False  False  False  False
# 1      False      False  False      False     False  False  False  False
# 2      False      False  False      False     False  False  False  False
# 3      False      False  False      False     False  False  False  False
# 4      False      False  False      False     False  False  False  False
# ...      ...        ...    ...        ...       ...    ...    ...    ...
# 29995  False      False  False      False     False  False  False  False
# 29996  False      False  False      False     False  False  False  False
# 29997  False      False  False      False     False  False  False  False
# 29998  False      False  False      False     False  False  False  False
# 29999  False      False  False      False     False  False  False  False
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ...

# %%
##Para crear dataframe con datos perdidos
    # pandas series denoting features and the sum of their null values
    null_sum = data.isnull(credit).sum()# instantiate columns for missing data
    total = null_sum.sort_values(ascending=False)
    percent = ( ((null_sum / len(data.index))*100).round(2) ).sort_values(ascending=False)
    
    # concatenate along the columns to create the complete dataframe
    df_NA = pd.concat([total, percent], axis=1, keys=['Number of NA', 'Percent NA'])
    
    # drop rows that don't have any missing data; omit if you want to keep all rows
    df_NA = df_NA[ (df_NA.T != 0).any() ]
    
    return df_NA
# Out:
#   File "<ipython-input-16-5a1a83144e02>", line 3
#     null_sum = data.isnull(credit)# instantiate columns for missing data
#     ^
# IndentationError: unexpected indent

# %%
def assess_NA(credit):
    """
    Returns a pandas dataframe denoting the total number of NA values and the percentage of NA values in each column.
    The column names are noted on the index.
    
    Parameters
    ----------
    data: dataframe
    """
    # pandas series denoting features and the sum of their null values
    null_sum = credit.isnull().sum()# instantiate columns for missing data
    total = null_sum.sort_values(ascending=False)
    percent = ( ((null_sum / len(credit.index))*100).round(2) ).sort_values(ascending=False)
    
    # concatenate along the columns to create the complete dataframe
    df_NA = pd.concat([total, percent], axis=1, keys=['Number of NA', 'Percent NA'])
    
    # drop rows that don't have any missing data; omit if you want to keep all rows
    df_NA = df_NA[ (df_NA.T != 0).any() ]
    
    return df_NA

# %%
print (df_NA)
# Out:
# Empty DataFrame
# Columns: [Number of NA, Percent NA]
# Index: []

# %%
df_NA
# Out:
# Empty DataFrame
# Columns: [Number of NA, Percent NA]
# Index: []

# %%
df_NA = assess_NA(credit)

# %%
print(df_NA)
# Out:
# Empty DataFrame
# Columns: [Number of NA, Percent NA]
# Index: []

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
plt.hist(credit['LIMIT_BAL'])
plt.show()

# %%
plt.hist(credit['LIMIT_BAL'], bins=4)
plt.show()

# %%
plt.hist(credit['PAY_0'])

plt.show()

# %%
plt.plot(credit['LIMIT_BAL'])
plt.show()

# %%
x = credit['PAY_0']
y = credit['PAY_2']

# %%
plt.scatter(x,y)
plt.show()

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
corrMat = credit.corr()
print(corrMat)
# Out:
#                                   ID  LIMIT_BAL       SEX  EDUCATION  \
# ID                          1.000000   0.026179  0.018497   0.039177
# LIMIT_BAL                   0.026179   1.000000  0.024755  -0.219161
# SEX                         0.018497   0.024755  1.000000   0.014232
# EDUCATION                   0.039177  -0.219161  0.014232   1.000000
# MARRIAGE                   -0.029079  -0.108139 -0.031389  -0.143464
# AGE                         0.018678   0.144713 -0.090874   0.175061
# PAY_0                      -0.030575  -0.271214 -0.057643   0.105364
# PAY_2                      -0.011215  -0.296382 -0.070771   0.121566
# PAY_3                      -0.018494  -0.286123 -0.066096   0.114025
# PAY_4                      -0.002735  -0.267460 -0.060173   0.108793
# PAY_5                      -0.022199  -0.249411 -0.055064   0.097520
# PAY_6                      -0.020270  -0.235195 -0.044008   0.082316
# BILL_AMT1                   0.019389   0.285430 -0.033642   0.023581
# ...

# %%
covMat = credit.cov()
print(covMat)
# Out:
#                                       ID     LIMIT_BAL          SEX  \
# ID                          7.500250e+07  2.941664e+07    78.356379
# LIMIT_BAL                   2.941664e+07  1.683446e+10  1571.050630
# SEX                         7.835638e+01  1.571051e+03     0.239247
# EDUCATION                   2.681543e+02 -2.247403e+04     0.005502
# MARRIAGE                   -1.314525e+02 -7.323670e+03    -0.008014
# AGE                         1.491057e+03  1.730767e+05    -0.409726
# PAY_0                      -2.975726e+02 -3.954593e+04    -0.031685
# PAY_2                      -1.162770e+02 -4.603765e+04    -0.041442
# PAY_3                      -1.916922e+02 -4.443225e+04    -0.038694
# PAY_4                      -2.769132e+01 -4.057181e+04    -0.034411
# PAY_5                      -2.178600e+02 -3.667056e+04    -0.030521
# PAY_6                      -2.018774e+02 -3.509308e+04    -0.024754
# BILL_AMT1                   1.236447e+07  2.727020e+09 -1211.694332
# ...

# %%
credit.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month'],
#       dtype='object')

# %%
# Number de cantidades por columna
credit.groupby('AGE')['AGE'].count()
# Out:
# AGE
# 21      67
# 22     560
# 23     931
# 24    1127
# 25    1186
# 26    1256
# 27    1477
# 28    1409
# 29    1605
# 30    1395
# 31    1217
# 32    1158
# 33    1146
# 34    1162
# 35    1113
# 36    1108
# 37    1041
# 38     944
# 39     954
# 40     870
# 41     824
# 42     794
# 43     670
# 44     700
# 45     617
# 46     570
# 47     501
# 48     466
# 49     452
# 50     411
# 51     340
# 52     304
# 53     325
# 54     247
# 55     209
# 56     178
# 57     122
# 58     122
# 59      83
# 60      67
# 61      56
# 62      44
# 63      31
# 64      31
# 65      24
# 66      25
# 67      16
# 68       5
# 69      15
# 70      10
# 71       3
# 72       3
# 73       4
# 74       1
# 75       3
# 79       1
# Name: AGE, dtype: int64

# %%
# Number de cantidades por columna
credit.groupby('PAY_0')['PAY_0'].count()
# Out:
# PAY_0
# -2     2759
# -1     5686
#  0    14737
#  1     3688
#  2     2667
#  3      322
#  4       76
#  5       26
#  6       11
#  7        9
#  8       19
# Name: PAY_0, dtype: int64

# %%
# Number de cantidades por columna
credit.groupby('PAY_2')['PAY_2'].count()
# Out:
# PAY_2
# -2     3782
# -1     6050
#  0    15730
#  1       28
#  2     3927
#  3      326
#  4       99
#  5       25
#  6       12
#  7       20
#  8        1
# Name: PAY_2, dtype: int64

# %%
# previous payment vs. age Grouped by age
sns.factorplot('PAY_AMT1','AGE', hue='age', data=credit, order=range(1,4))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-d7073276550c> in <module>
#       1 # previous payment vs. age Grouped by age
# ----> 2 sns.factorplot('PAY_AMT1','AGE', hue='age', data=credit, order=range(1,4))
#       3
#       4
#       5
#
# NameError: name 'sns' is not defined

# %%
import seaborn as sns

# %%
# previous payment vs. age Grouped by age
sns.factorplot('PAY_AMT1','AGE', hue='age', data=credit, order=range(1,4))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-52c0eea9376a> in <module>
#       1 # previous payment vs. age Grouped by age
# ----> 2 sns.factorplot('PAY_AMT1','AGE', hue='age', data=credit, order=range(1,4))
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in factorplot(*args, **kwargs)
#    3674     kwargs.setdefault("kind", "point")
#    3675
# -> 3676     return catplot(*args, **kwargs)
#    3677
#    3678
#
# ...

# %%
# 
credit.pivot_table('AGE', 'LIMIT_BAL', 'PAY_AMT1', aggfunc=np.sum, margins=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-2b46fc2cff94> in <module>
#       1 #
# ----> 2 credit.pivot_table('AGE', 'LIMIT_BAL', 'PAY_AMT1', aggfunc=np.sum, margins=True)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
credit.pivot_table('AGE', 'LIMIT_BAL', 'PAY_AMT1', aggfunc=np.sum, margins=True)
# Out:
# PAY_AMT1          0      1      2      3      4      5      6      7      8  \
# LIMIT_BAL
# 10000        4025.0    NaN   50.0    NaN    NaN    NaN    NaN    NaN    NaN
# 16000          48.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 20000       14682.0    NaN  121.0    NaN   78.0    NaN    NaN    NaN   27.0
# 30000       12052.0   78.0    NaN    NaN    NaN    NaN   52.0   25.0    NaN
# 40000        1764.0    NaN    NaN   42.0    NaN    NaN    NaN    NaN    NaN
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# 760000          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 780000          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 800000          NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1000000         NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# All        187904.0  344.0  519.0  541.0  722.0  386.0  529.0  257.0  247.0
#
# ...

# %%
# Number de cantidades por columna
credit.groupby('SEX')['SEX'].count()
# Out:
# SEX
# 1    11888
# 2    18112
# Name: SEX, dtype: int64

# %%
plt.hist(credit['SEX'])

plt.show()

# %%
# Instead of a group by, Use sex
fg = sns.factorplot('SEX', data=credit, kind='count', aspect=1.5)
fg.set_xlabels('Sex')

# %%
# Again use saeborn to group by Sex and marriage
g = sns.factorplot('MARRIAGE', data=credit, hue='SEX', kind='count', aspect=1.75)
g.set_xlabels('Marriage')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
# Again use saeborn to group by Sex default payment next month
g = sns.factorplot('default payment next month', data=credit, hue='SEX', kind='count', aspect=1.75)
g.set_xlabels('default payment next month')
